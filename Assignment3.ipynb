# %%
# 1) Practise
# 	Dictionary
# 	Tuple
# 	Set


dic = {"name": "Nikhil", "age": 25, "city": "Delhi"}
Nested_dic = {"name": "Nikhil", "age": 25, "city": "Delhi", "hobbies": {"1":"coding", "2": "gaming", "3": "traveling"}}
print(dic["name"])
print(dic["age"])
print(dic["city"])

print(Nested_dic["hobbies"]["2"])
dic["age"] = 21
dic["city"] = "Jaipur"
dic["country"] = "India"
print(dic.keys())
print(dic.values())
print(dic)

del(dic["country"])
print(dic)

dic.update({"country": "India"})
print(dic)

dic.pop("age")
print(dic)

dic.clear()
print(dic)
print("\n")


#Tuples
t1 = ("Nikhil", 25, "Delhi")
t2 = ("Mohit", 30, "Mumbai")
print(t1[0])

l = len(t1)
for i in range(l):
    print(t1[i])

print(t1+t2)
t3 = (t1,t2)
print(t3)

t4 = (1,2,3,4,5)
print(t4[1:4])
print(t4[::2])
print(t4[::-1])

del(t4)
l = [1,2,3,4,5]
t5 = tuple(l)
print(t5)
print(t5.count(3))
print(t5.index(4))
print(max(t5))
print(min(t5))
print(sum(t5))
print("\n")

#sets
s1 = {1,2,3,4,5}
s2 = {4,5,6,7,8}
print(s1)
print(s2)
print(s1.union(s2))
print(s1.intersection(s2))
print(s1.difference(s2))
print(s1.symmetric_difference(s2))
s1.add(6)
print(s1)
s1.remove(6)
print(s1)
s1.discard(6)
print(s1)
s1.clear()
print(s1)

# %%
# 2) Write a function for basic math operations like add multiply substract divide and use this in your program, take 2 number input from user.

def add(a, b):
    return a + b
def subtract(a, b):
    return a - b
def multiply(a, b):
    return a * b
def divide(a, b):
    if b != 0:
        return a / b
    else:
        print("Error: Division by zero is not allowed.")


num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
print(f"Addition: {add(num1, num2)}")
print(f"Subtraction: {subtract(num1, num2)}")
print(f"Multiplication: {multiply(num1, num2)}")
print(f"Division : {divide(num1, num2)}")

# %%
# 3) Write a program to check Palindrome Number

#  For example Number 12321 is a Palindrome Number, because 12321 is equal to its reverse Number 12321.

num = int(input("Enter a number: "))
original = num
reverse_num = 0
while num > 0:
    lastdigit = num%10
    reverse_num = reverse_num*10 + lastdigit
    num = num//10

if original == reverse_num:
    print(f"{original} is a palindrome.")
else:
    print(f"{original} is not a palindrome.")
# Out:
# 123 is not a palindrome.
